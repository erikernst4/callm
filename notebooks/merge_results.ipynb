# %%
import pandas as pd

# %%
eval_dir = "/home/eernst/callm/lightning_logs/label_prob_evaluation/version_7/"
confidences_dir = "/home/eernst/callm/lightning_logs/version_7/"

# %%
df_eval_results = pd.read_csv(f"{eval_dir}/evaluation_results.csv")
df_confidences = pd.read_csv(f"{confidences_dir}/llm_outputs.csv")

# %%
df_eval_results.columns

# %%
df_confidences.columns

# %%
df_eval_results.iloc[0]

# %%
df_confidences.iloc[0]

# %%
df_merged = df_eval_results.copy()
df_merged["Confidence"] = df_confidences["confidence"]
df_merged.iloc[0]

# %%
df_merged.to_csv(f"{confidences_dir}/merged_results.csv", index=False)
