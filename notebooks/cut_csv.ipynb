# %%
import pandas as pd

# %%
confidences_dir = "/home/eernst/callm/lightning_logs/verbalized_Qwen3.5-9B"

# %%
df_confidences = pd.read_csv(f"{confidences_dir}/llm_outputs.csv")

# %%
len(df_confidences)

# %%
len(df_confidences[:1000])

# %%
df_confidences[:1000].to_csv(f"{confidences_dir}/first_1000_results.csv", index=False)
